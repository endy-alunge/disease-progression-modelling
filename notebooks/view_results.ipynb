# %%
# Run this after executing `main.py` to view and analyze results.

# %%
import sys
sys.path.append('..')
import os
from IPython.display import Image, display
import matplotlib.pyplot as plt

OUTPUT_DIR = '../outputs'
FIGURES_DIR = f'{OUTPUT_DIR}/figures'

# Cell 3: Print summary
with open(f'{OUTPUT_DIR}/results_summary.txt', 'r') as f:
    print(f.read())

# %%
figures = [
    'fig1_confusion_diag.png',
    'fig2_confusion_prog.png', 
    'fig3_markov_transitions.png',
    'fig4_hmm_structure.png',
    'fig5_rnn_training.png',
    'fig6_model_comparison.png',
    'fig9_robustness.png'
]

for fig in figures:
    print(f"\n{'='*50}\n{fig}\n{'='*50}")
    img_path = f'{FIGURES_DIR}/{fig}'
    if os.path.exists(img_path):
        display(Image(filename=img_path))
    else:
        print(f"File not found: {img_path}")

# %%
with open(f'{OUTPUT_DIR}/results_summary.txt', 'r') as f:
    print(f.read())
